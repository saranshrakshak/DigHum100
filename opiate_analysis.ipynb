# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Dataset provided by the Center for Medicare and Medicaid Services, which can be accessed here:
# https://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/OpioidMap

# %%
op_data = pd.read_csv("op_data.csv")
op_data
# Out:
#       Prscrbr_Geo_Lvl  Prscrbr_Geo_Cd                    Prscrbr_Geo_Desc  \
# 0            National             NaN                            National
# 1            National             NaN                            National
# 2            National             NaN                            National
# 3               State             1.0                             Alabama
# 4               State             1.0                             Alabama
# ...               ...             ...                                 ...
# 30855             ZIP         99922.0  Alaska:Prince of Wales-Hyder:99922
# 30856             ZIP         99925.0  Alaska:Prince of Wales-Hyder:99925
# 30857             ZIP         99926.0  Alaska:Prince of Wales-Hyder:99926
# 30858             ZIP         99928.0      Alaska:Ketchikan Gateway:99928
# 30859             ZIP         99929.0               Alaska:Wrangell:99929
#
#        RUCA_Cd RUCA_Desc  Tot_Prscrbrs_13  Tot_Opioid_Prscrbrs_13  \
# 0          NaN       All        1048050.0                814104.0
# 1          NaN     Rural         118464.0                 97218.0
# 2          NaN     Urban         927954.0                715565.0
# 3          NaN       All          12815.0                 10772.0
# 4          NaN     Rural           1911.0                  1667.0
# ...        ...       ...              ...                     ...
# 30855     10.0     Rural              2.0                     1.0
# 30856     10.0     Rural              7.0                     6.0
# 30857     10.0     Rural              1.0                     1.0
# 30858      4.0     Rural              NaN                     NaN
# 30859     10.0     Rural              7.0                     7.0
#
#        Tot_Opioid_Clms_13   Tot_Clms_13  Opioid_Prscrbng_Rate_13  ...  \
# 0              79542093.0  1.366842e+09                     5.82  ...
# 1              15757940.0  2.586565e+08                     6.09  ...
# 2              63733799.0  1.107261e+09                     5.76  ...
# 3               2266194.0  2.913260e+07                     7.78  ...
# 4                553466.0  7.423058e+06                     7.46  ...
# ...                   ...           ...                      ...  ...
# 30855                 NaN  1.510000e+02                      NaN  ...
# 30856               641.0  4.644000e+03                    13.80  ...
# 30857                38.0  4.970000e+02                     7.65  ...
# 30858                 NaN           NaN                      NaN  ...
# 30859               448.0  5.824000e+03                     7.69  ...
#
#        Tot_Opioid_Prscrbrs_18  Tot_Opioid_Clms_18   Tot_Clms_18  \
# 0                    812987.0          70196574.0  1.498483e+09
# 1                     96020.0          12668611.0  2.635614e+08
# 2                    715899.0          57482703.0  1.233870e+09
# 3                      9869.0           1938707.0  2.810694e+07
# 4                      1397.0            429622.0  6.656126e+06
# ...                       ...                 ...           ...
# 30855                     0.0                 0.0  6.800000e+01
# 30856                     2.0                97.0  1.718000e+03
# 30857                     1.0                30.0  9.500000e+01
# 30858                     NaN                 NaN           NaN
# 30859                     3.0               183.0  3.878000e+03
#
#        Opioid_Prscrbng_Rate_18  Opioid_Prscrbng_Rate_Chg_1813  \
# 0                         4.68                          -1.14
# 1                         4.81                          -1.28
# 2                         4.66                          -1.10
# 3                         6.90                          -0.88
# 4                         6.45                          -1.01
# ...                        ...                            ...
# 30855                     0.00                            NaN
# 30856                     5.65                          -8.15
# 30857                    31.58                          23.93
# 30858                      NaN                            NaN
# 30859                     4.72                          -2.97
#
#        Opioid_Prscrbng_Rate_Chg_1817  LA_Tot_Opioid_Clms_18  \
# 0                              -0.38              8275508.0
# 1                              -0.38              1332214.0
# 2                              -0.37              6939940.0
# 3                              -0.31               162063.0
# 4                              -0.52                27561.0
# ...                              ...                    ...
# 30855                         -12.65                    0.0
# 30856                          -1.25                    NaN
# 30857                          -5.67                    0.0
# 30858                            NaN                    NaN
# 30859                          -1.37                   38.0
#
#        LA_Opioid_Prscrbng_Rate_18  LA_Opioid_Prscrbng_Rate_Chg_1813  \
# 0                           11.79                             -0.94
# 1                           10.52                             -1.39
# 2                           12.07                             -0.86
# 3                            8.36                             -1.36
# 4                            6.42                             -1.33
# ...                           ...                               ...
# 30855                         NaN                               NaN
# 30856                         NaN                               NaN
# 30857                        0.00                               NaN
# 30858                         NaN                               NaN
# 30859                       20.77                              0.46
#
#        LA_Opioid_Prscrbng_Rate_Chg_1817
# 0                                 -0.66
# 1                                 -0.82
# 2                                 -0.63
# 3                                 -0.97
# 4                                 -1.53
# ...                                 ...
# 30855                               NaN
# 30856                               NaN
# 30857                              0.00
# 30858                               NaN
# 30859                             -0.23
#
# [30860 rows x 51 columns]
